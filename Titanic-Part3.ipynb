# %% [markdown]
# # Part 3. AutoML
#
# 1. Train an AutoML model locally
# 2. Customizability of Azure AutoML
#
# ## Setup
#
# ```
# pip install azureml-sdk[automl]
#
# # for mac:
# brew install lightgbm
# brew install libomp
# ```

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm
import logging

# %% [markdown]
# ## Workspace

# %%
import os

subscription_id = os.getenv("SUBSCRIPTION_ID")
resource_group = os.getenv("RESOURCE_GROUP")
workspace_name = os.getenv("WORKSPACE_NAME")
workspace_region = os.getenv("WORKSPACE_REGION")

from azureml.core import Workspace
ws = Workspace(subscription_id = subscription_id, resource_group = resource_group, workspace_name = workspace_name)

# %% [markdown]
# # Train an AutoML model locally

# %%
df = pd.read_csv('data/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
from azureml.train.automl import AutoMLConfig
# https://docs.microsoft.com/en-us/azure/machine-learning/service/how-to-configure-auto-train#configure-your-experiment-settings
# https://docs.microsoft.com/en-us/python/api/azureml-train-automl/azureml.train.automl.automlconfig?view=azure-ml-py
automl_config = AutoMLConfig(
    task='classification',
    training_data=df,
    label_column_name='Survived',
    primary_metric='AUC_weighted',
    n_cross_validations=2,
    
    # Try for at most 10 minutes, then give up.
    experiment_timeout_minutes=1,
    
    # Featurization
    preprocess=True,
    
    debug_log="automated_ml_errors.log",
    verbosity=logging.INFO)

# %%
from azureml.core import Experiment
experiment = Experiment(ws, "titanic-automl-local-22")
local_run = experiment.submit(automl_config, show_output=True)
# Out:
# Running on local machine
# Parent Run ID: AutoML_f270975e-99da-4b04-8835-4d7e4860afe0
# Current status: DatasetFeaturization. Beginning to featurize the dataset.
# Current status: DatasetEvaluation. Gathering dataset statistics.
# Current status: FeaturesGeneration. Generating features for the dataset.
# Current status: DatasetFeaturizationCompleted. Completed featurizing the dataset.
# Current status: DatasetCrossValidationSplit. Generating individually featurized CV splits.
#
# ****************************************************************************************************
# DATA GUARDRAILS SUMMARY:
# For more details, use API: run.get_guardrails()
#
# TYPE:         Class Balancing Detection
# STATUS:       PASSED
# DESCRIPTION:  Classes are balanced in the training data.
#
# TYPE:         Missing Values Imputation
# STATUS:       FIXED
# DESCRIPTION:  The training data had the following missing values which were resolved.
#
# Please review your data source for data quality issues and possibly filter out the rows with these missing values.
#
# If the missing values are expected, you can either accept the above imputation, or implement your own custom imputation that may be more appropriate based on the data type and business process.
#
#
# TYPE:         High Cardinality Feature Detection
# STATUS:       DONE
# DESCRIPTION:  High cardinality inputs were detected in dataset and were featurized as text.
#
# ****************************************************************************************************
# Current status: ModelSelection. Beginning model selection.
#
# ****************************************************************************************************
# ITERATION: The iteration being evaluated.
# PIPELINE: A summary description of the pipeline being evaluated.
# DURATION: Time taken for the current iteration.
# METRIC: The result of computing score on the fitted pipeline.
# BEST: The best observed score thus far.
# ****************************************************************************************************
#
#  ITERATION   PIPELINE                                       DURATION      METRIC      BEST
#          0   MaxAbsScaler LightGBM                          0:00:17       0.8649    0.8649
#          1   MaxAbsScaler SGD                               0:00:17       0.8524    0.8649
#          2   StandardScalerWrapper LightGBM                 0:00:16       0.8626    0.8649
#          3   MaxAbsScaler RandomForest                      0:00:16       0.8243    0.8649
#          4   VotingEnsemble                                 0:00:24       0.8683    0.8683
#          5   StackEnsemble                                  0:00:26       0.8661    0.8683
# Stopping criteria reached at iteration 5. Ending experiment.

# %%
local_run
# Out:
# Run(Experiment: titanic-automl-local-22,
# Id: AutoML_f270975e-99da-4b04-8835-4d7e4860afe0,
# Type: automl,
# Status: Completed)

# %%
from azureml.widgets import RunDetails
RunDetails(local_run).show()
# Out:
# _AutoMLWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', 's…

# %%
best_run, fitted_model = local_run.get_output()
# print(best_run)
print(fitted_model)
# Out:
# Pipeline(memory=None,
#      steps=[('datatransformer', DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#         feature_sweeping_config=None, feature_sweeping_timeout=None,
#         featurization_config=None, is_cross_validation=None,
#         is_onnx_compatible=None, logger=None, observer=None, task=None)), ('pref...      weights=[0.35714285714285715, 0.21428571428571427, 0.2857142857142857, 0.14285714285714285]))])

# %%
fitted_model.named_steps.keys()
# Out:
# dict_keys(['datatransformer', 'prefittedsoftvotingclassifier'])

# %% [markdown]
# ## Dig into the Featurizations done

# %%
summary_ = fitted_model.named_steps['datatransformer'].get_featurization_summary()

from pprint import pprint
pprint(summary_)
# Out:
# [{'Dropped': 'No',
#   'EngineeredFeatureCount': 2,
#   'RawFeatureName': 'Age',
#   'Transformations': ['MeanImputer', 'ImputationMarker'],
#   'TypeDetected': 'Numeric'},
#  {'Dropped': 'No',
#   'EngineeredFeatureCount': 1,
#   'RawFeatureName': 'Fare',
#   'Transformations': ['MeanImputer'],
#   'TypeDetected': 'Numeric'},
#  {'Dropped': 'No',
#   'EngineeredFeatureCount': 1,
#   'RawFeatureName': 'PassengerId',
#   'Transformations': ['MeanImputer'],
#   'TypeDetected': 'Numeric'},
#  {'Dropped': 'Yes',
#   'EngineeredFeatureCount': 0,
#   'RawFeatureName': 'Cabin',
#   'Transformations': [''],
#   'TypeDetected': 'Ignore'},
#  {'Dropped': 'Yes',
#   'EngineeredFeatureCount': 0,
#   'RawFeatureName': 'Ticket',
#   'Transformations': [''],
#   'TypeDetected': 'Ignore'},
#  {'Dropped': 'No',
#   'EngineeredFeatureCount': 4,
#   'RawFeatureName': 'Embarked',
#   'Transformations': ['StringCast-CharGramCountVectorizer'],
#   'TypeDetected': 'Categorical'},
#  {'Dropped': 'No',
#   'EngineeredFeatureCount': 7,
#   'RawFeatureName': 'Parch',
#   'Transformations': ['StringCast-CharGramCountVectorizer'],
#   'TypeDetected': 'Categorical'},
#  {'Dropped': 'No',
#   'EngineeredFeatureCount': 3,
#   'RawFeatureName': 'Pclass',
#   'Transformations': ['StringCast-CharGramCountVectorizer'],
#   'TypeDetected': 'Categorical'},
#  {'Dropped': 'No',
#   'EngineeredFeatureCount': 1,
#   'RawFeatureName': 'Sex',
#   'Transformations': ['ModeCatImputer-StringCast-LabelEncoder'],
#   'TypeDetected': 'Categorical'},
#  {'Dropped': 'No',
#   'EngineeredFeatureCount': 7,
#   'RawFeatureName': 'SibSp',
#   'Transformations': ['StringCast-CharGramCountVectorizer'],
#   'TypeDetected': 'Categorical'},
#  {'Dropped': 'No',
#   'EngineeredFeatureCount': 6948,
#   'RawFeatureName': 'Name',
#   'Transformations': ['StringCast-CharGramTfIdf', 'StringCast-WordGramTfIdf'],
#   'TypeDetected': 'Text'}]

# %%
fitted_model.named_steps['datatransformer'].get_engineered_feature_names()
# Out:
# ['Age_MeanImputer',
#  'Age_ImputationMarker',
#  'Fare_MeanImputer',
#  'PassengerId_MeanImputer',
#  'Embarked_CharGramCountVectorizer_c',
#  'Embarked_CharGramCountVectorizer_nan',
#  'Embarked_CharGramCountVectorizer_q',
#  'Embarked_CharGramCountVectorizer_s',
#  'Parch_CharGramCountVectorizer_0',
#  'Parch_CharGramCountVectorizer_1',
#  'Parch_CharGramCountVectorizer_2',
#  'Parch_CharGramCountVectorizer_3',
#  'Parch_CharGramCountVectorizer_4',
#  'Parch_CharGramCountVectorizer_5',
#  'Parch_CharGramCountVectorizer_6',
#  'Pclass_CharGramCountVectorizer_1',
#  'Pclass_CharGramCountVectorizer_2',
#  'Pclass_CharGramCountVectorizer_3',
#  'Sex_ModeCatImputer_LabelEncoder',
#  'SibSp_CharGramCountVectorizer_0',
#  'SibSp_CharGramCountVectorizer_1',
#  'SibSp_CharGramCountVectorizer_2',
#  'SibSp_CharGramCountVectorizer_3',
#  'SibSp_CharGramCountVectorizer_4',
#  'SibSp_CharGramCountVectorizer_5',
#  'SibSp_CharGramCountVectorizer_8',
#  'Name_CharGramTfIdf_ "a',
#  'Name_CharGramTfIdf_ "b',
#  'Name_CharGramTfIdf_ "c',
#  'Name_CharGramTfIdf_ "d',
#  'Name_CharGramTfIdf_ "e',
#  'Name_CharGramTfIdf_ "f',
#  'Name_CharGramTfIdf_ "g',
#  'Name_CharGramTfIdf_ "h',
#  'Name_CharGramTfIdf_ "j',
#  'Name_CharGramTfIdf_ "k',
#  'Name_CharGramTfIdf_ "l',
#  'Name_CharGramTfIdf_ "m',
#  'Name_CharGramTfIdf_ "n',
#  'Name_CharGramTfIdf_ "r',
#  'Name_CharGramTfIdf_ "s',
#  'Name_CharGramTfIdf_ "w',
#  'Name_CharGramTfIdf_ ("',
#  'Name_CharGramTfIdf_ (a',
#  'Name_CharGramTfIdf_ (b',
#  'Name_CharGramTfIdf_ (c',
#  'Name_CharGramTfIdf_ (d',
#  'Name_CharGramTfIdf_ (e',
#  'Name_CharGramTfIdf_ (f',
#  'Name_CharGramTfIdf_ (g',
#  'Name_CharGramTfIdf_ (h',
#  'Name_CharGramTfIdf_ (i',
#  'Name_CharGramTfIdf_ (j',
#  'Name_CharGramTfIdf_ (k',
#  'Name_CharGramTfIdf_ (l',
#  'Name_CharGramTfIdf_ (m',
#  'Name_CharGramTfIdf_ (r',
#  'Name_CharGramTfIdf_ (s',
#  'Name_CharGramTfIdf_ (t',
#  'Name_CharGramTfIdf_ (v',
#  'Name_CharGramTfIdf_ a ',
#  'Name_CharGramTfIdf_ aa',
#  'Name_CharGramTfIdf_ ab',
#  'Name_CharGramTfIdf_ ac',
#  'Name_CharGramTfIdf_ ad',
#  'Name_CharGramTfIdf_ ag',
#  'Name_CharGramTfIdf_ ah',
#  'Name_CharGramTfIdf_ ai',
#  'Name_CharGramTfIdf_ al',
#  'Name_CharGramTfIdf_ am',
#  'Name_CharGramTfIdf_ an',
#  'Name_CharGramTfIdf_ ap',
#  'Name_CharGramTfIdf_ ar',
#  'Name_CharGramTfIdf_ as',
#  'Name_CharGramTfIdf_ at',
#  'Name_CharGramTfIdf_ au',
#  'Name_CharGramTfIdf_ ba',
#  'Name_CharGramTfIdf_ be',
#  'Name_CharGramTfIdf_ bi',
#  'Name_CharGramTfIdf_ bl',
#  'Name_CharGramTfIdf_ bo',
#  'Name_CharGramTfIdf_ br',
#  'Name_CharGramTfIdf_ bu',
#  'Name_CharGramTfIdf_ c ',
#  'Name_CharGramTfIdf_ ca',
#  'Name_CharGramTfIdf_ ce',
#  'Name_CharGramTfIdf_ ch',
#  'Name_CharGramTfIdf_ cl',
#  'Name_CharGramTfIdf_ co',
#  'Name_CharGramTfIdf_ cr',
#  'Name_CharGramTfIdf_ cu',
#  'Name_CharGramTfIdf_ cy',
#  'Name_CharGramTfIdf_ d ',
#  'Name_CharGramTfIdf_ da',
#  'Name_CharGramTfIdf_ de',
#  'Name_CharGramTfIdf_ di',
#  'Name_CharGramTfIdf_ do',
#  'Name_CharGramTfIdf_ dr',
#  'Name_CharGramTfIdf_ du',
#  'Name_CharGramTfIdf_ dy',
#  'Name_CharGramTfIdf_ e ',
#  'Name_CharGramTfIdf_ eb',
#  'Name_CharGramTfIdf_ ed',
#  'Name_CharGramTfIdf_ ei',
#  'Name_CharGramTfIdf_ el',
#  'Name_CharGramTfIdf_ em',
#  'Name_CharGramTfIdf_ en',
#  'Name_CharGramTfIdf_ er',
#  'Name_CharGramTfIdf_ es',
#  'Name_CharGramTfIdf_ et',
#  'Name_CharGramTfIdf_ eu',
#  'Name_CharGramTfIdf_ ev',
#  'Name_CharGramTfIdf_ fa',
#  'Name_CharGramTfIdf_ fe',
#  'Name_CharGramTfIdf_ fi',
#  'Name_CharGramTfIdf_ fl',
#  'Name_CharGramTfIdf_ fo',
#  'Name_CharGramTfIdf_ fr',
#  'Name_CharGramTfIdf_ fu',
#  'Name_CharGramTfIdf_ g ',
#  'Name_CharGramTfIdf_ ga',
#  'Name_CharGramTfIdf_ ge',
#  'Name_CharGramTfIdf_ gi',
#  'Name_CharGramTfIdf_ gl',
#  'Name_CharGramTfIdf_ go',
#  'Name_CharGramTfIdf_ gr',
#  'Name_CharGramTfIdf_ gu',
#  'Name_CharGramTfIdf_ h ',
#  'Name_CharGramTfIdf_ ha',
#  'Name_CharGramTfIdf_ he',
#  'Name_CharGramTfIdf_ hi',
#  'Name_CharGramTfIdf_ hj',
#  'Name_CharGramTfIdf_ ho',
#  'Name_CharGramTfIdf_ hu',
#  'Name_CharGramTfIdf_ id',
#  'Name_CharGramTfIdf_ ig',
#  'Name_CharGramTfIdf_ ii',
#  'Name_CharGramTfIdf_ il',
#  'Name_CharGramTfIdf_ im',
#  'Name_CharGramTfIdf_ in',
#  'Name_CharGramTfIdf_ ir',
#  'Name_CharGramTfIdf_ iv',
#  'Name_CharGramTfIdf_ j ',
#  'Name_CharGramTfIdf_ ja',
#  'Name_CharGramTfIdf_ je',
#  'Name_CharGramTfIdf_ jo',
#  'Name_CharGramTfIdf_ jr',
#  'Name_CharGramTfIdf_ ju',
#  'Name_CharGramTfIdf_ k ',
#  'Name_CharGramTfIdf_ ka',
#  'Name_CharGramTfIdf_ kh',
#  'Name_CharGramTfIdf_ ki',
#  'Name_CharGramTfIdf_ kl',
#  'Name_CharGramTfIdf_ kn',
#  'Name_CharGramTfIdf_ ko',
#  'Name_CharGramTfIdf_ kr',
#  'Name_CharGramTfIdf_ ku',
#  'Name_CharGramTfIdf_ l ',
#  'Name_CharGramTfIdf_ l)',
#  'Name_CharGramTfIdf_ l.',
#  'Name_CharGramTfIdf_ la',
#  'Name_CharGramTfIdf_ le',
#  'Name_CharGramTfIdf_ li',
#  'Name_CharGramTfIdf_ lo',
#  'Name_CharGramTfIdf_ lu',
#  'Name_CharGramTfIdf_ ly',
#  'Name_CharGramTfIdf_ m ',
#  'Name_CharGramTfIdf_ ma',
#  'Name_CharGramTfIdf_ mc',
#  'Name_CharGramTfIdf_ me',
#  'Name_CharGramTfIdf_ mi',
#  'Name_CharGramTfIdf_ ml',
#  'Name_CharGramTfIdf_ mm',
#  'Name_CharGramTfIdf_ mo',
#  'Name_CharGramTfIdf_ mr',
#  'Name_CharGramTfIdf_ ms',
#  'Name_CharGramTfIdf_ mu',
#  'Name_CharGramTfIdf_ na',
#  'Name_CharGramTfIdf_ ne',
#  'Name_CharGramTfIdf_ ni',
#  'Name_CharGramTfIdf_ no',
#  'Name_CharGramTfIdf_ oa',
#  'Name_CharGramTfIdf_ ob',
#  'Name_CharGramTfIdf_ of',
#  'Name_CharGramTfIdf_ og',
#  'Name_CharGramTfIdf_ oj',
#  'Name_CharGramTfIdf_ ol',
#  'Name_CharGramTfIdf_ or',
#  'Name_CharGramTfIdf_ os',
#  'Name_CharGramTfIdf_ ow',
#  'Name_CharGramTfIdf_ pa',
#  'Name_CharGramTfIdf_ pe',
#  'Name_CharGramTfIdf_ ph',
#  'Name_CharGramTfIdf_ pi',
#  'Name_CharGramTfIdf_ pl',
#  'Name_CharGramTfIdf_ po',
#  'Name_CharGramTfIdf_ pr',
#  'Name_CharGramTfIdf_ qu',
#  'Name_CharGramTfIdf_ r ',
#  'Name_CharGramTfIdf_ ra',
#  'Name_CharGramTfIdf_ re',
#  'Name_CharGramTfIdf_ ri',
#  'Name_CharGramTfIdf_ ro',
#  'Name_CharGramTfIdf_ ru',
#  'Name_CharGramTfIdf_ s ',
#  'Name_CharGramTfIdf_ sa',
#  'Name_CharGramTfIdf_ sc',
#  'Name_CharGramTfIdf_ se',
#  'Name_CharGramTfIdf_ sh',
#  'Name_CharGramTfIdf_ si',
#  'Name_CharGramTfIdf_ sl',
#  'Name_CharGramTfIdf_ so',
#  'Name_CharGramTfIdf_ sp',
#  'Name_CharGramTfIdf_ st',
#  'Name_CharGramTfIdf_ su',
#  'Name_CharGramTfIdf_ sv',
#  'Name_CharGramTfIdf_ sy',
#  'Name_CharGramTfIdf_ t ',
#  'Name_CharGramTfIdf_ ta',
#  'Name_CharGramTfIdf_ te',
#  'Name_CharGramTfIdf_ th',
#  'Name_CharGramTfIdf_ ti',
#  'Name_CharGramTfIdf_ to',
#  'Name_CharGramTfIdf_ tr',
#  'Name_CharGramTfIdf_ ty',
#  'Name_CharGramTfIdf_ ul',
#  'Name_CharGramTfIdf_ ur',
#  'Name_CharGramTfIdf_ us',
#  'Name_CharGramTfIdf_ v ',
#  'Name_CharGramTfIdf_ va',
#  'Name_CharGramTfIdf_ ve',
#  'Name_CharGramTfIdf_ vi',
#  'Name_CharGramTfIdf_ w ',
#  'Name_CharGramTfIdf_ wa',
#  'Name_CharGramTfIdf_ we',
#  'Name_CharGramTfIdf_ wh',
#  'Name_CharGramTfIdf_ wi',
#  'Name_CharGramTfIdf_ wo',
#  'Name_CharGramTfIdf_ wr',
#  'Name_CharGramTfIdf_ wy',
#  'Name_CharGramTfIdf_ y ',
#  'Name_CharGramTfIdf_ yo',
#  'Name_CharGramTfIdf_ ze',
#  'Name_CharGramTfIdf_ zi',
#  'Name_CharGramTfIdf_" a',
#  'Name_CharGramTfIdf_" g',
#  'Name_CharGramTfIdf_" i',
#  'Name_CharGramTfIdf_"an',
#  'Name_CharGramTfIdf_"ar',
#  'Name_CharGramTfIdf_"be',
#  'Name_CharGramTfIdf_"ca',
#  'Name_CharGramTfIdf_"da',
#  'Name_CharGramTfIdf_"do',
#  'Name_CharGramTfIdf_"el',
#  'Name_CharGramTfIdf_"fa',
#  'Name_CharGramTfIdf_"fr',
#  'Name_CharGramTfIdf_"ge',
#  'Name_CharGramTfIdf_"gu',
#  'Name_CharGramTfIdf_"ha',
#  'Name_CharGramTfIdf_"he',
#  'Name_CharGramTfIdf_"ir',
#  'Name_CharGramTfIdf_"ja',
#  'Name_CharGramTfIdf_"ka',
#  'Name_CharGramTfIdf_"lo',
#  'Name_CharGramTfIdf_"ma',
#  'Name_CharGramTfIdf_"mi',
#  'Name_CharGramTfIdf_"mr',
#  'Name_CharGramTfIdf_"ne',
#  'Name_CharGramTfIdf_"ni',
#  'Name_CharGramTfIdf_"no',
#  'Name_CharGramTfIdf_"pe',
#  'Name_CharGramTfIdf_"ph',
#  'Name_CharGramTfIdf_"ru',
#  'Name_CharGramTfIdf_"su',
#  'Name_CharGramTfIdf_"we',
#  'Name_CharGramTfIdf_"wi',
#  "Name_CharGramTfIdf_'br",
#  "Name_CharGramTfIdf_'co",
#  "Name_CharGramTfIdf_'dr",
#  "Name_CharGramTfIdf_'dw",
#  "Name_CharGramTfIdf_'le",
#  "Name_CharGramTfIdf_'su",
#  'Name_CharGramTfIdf_("g',
#  'Name_CharGramTfIdf_("h',
#  'Name_CharGramTfIdf_("i',
#  'Name_CharGramTfIdf_("l',
#  'Name_CharGramTfIdf_("m',
#  'Name_CharGramTfIdf_("p',
#  'Name_CharGramTfIdf_("w',
#  'Name_CharGramTfIdf_(ad',
#  'Name_CharGramTfIdf_(ag',
#  'Name_CharGramTfIdf_(al',
#  'Name_CharGramTfIdf_(am',
#  'Name_CharGramTfIdf_(an',
#  'Name_CharGramTfIdf_(au',
#  'Name_CharGramTfIdf_(be',
#  'Name_CharGramTfIdf_(ca',
#  'Name_CharGramTfIdf_(ch',
#  'Name_CharGramTfIdf_(cl',
#  'Name_CharGramTfIdf_(co',
#  'Name_CharGramTfIdf_(da',
#  'Name_CharGramTfIdf_(do',
#  'Name_CharGramTfIdf_(ed',
#  'Name_CharGramTfIdf_(el',
#  'Name_CharGramTfIdf_(em',
#  'Name_CharGramTfIdf_(es',
#  'Name_CharGramTfIdf_(et',
#  'Name_CharGramTfIdf_(fa',
#  'Name_CharGramTfIdf_(fl',
#  'Name_CharGramTfIdf_(gr',
#  'Name_CharGramTfIdf_(ha',
#  'Name_CharGramTfIdf_(he',
#  'Name_CharGramTfIdf_(id',
#  'Name_CharGramTfIdf_(im',
#  'Name_CharGramTfIdf_(ir',
#  'Name_CharGramTfIdf_(ja',
#  'Name_CharGramTfIdf_(je',
#  'Name_CharGramTfIdf_(jo',
#  'Name_CharGramTfIdf_(ju',
#  'Name_CharGramTfIdf_(ka',
#  'Name_CharGramTfIdf_(la',
#  'Name_CharGramTfIdf_(le',
#  'Name_CharGramTfIdf_(li',
#  'Name_CharGramTfIdf_(lu',
#  'Name_CharGramTfIdf_(ma',
#  'Name_CharGramTfIdf_(mi',
#  'Name_CharGramTfIdf_(my',
#  'Name_CharGramTfIdf_(ro',
#  'Name_CharGramTfIdf_(sa',
#  'Name_CharGramTfIdf_(se',
#  'Name_CharGramTfIdf_(su',
#  'Name_CharGramTfIdf_(sy',
#  'Name_CharGramTfIdf_(ti',
#  'Name_CharGramTfIdf_(ve',
#  'Name_CharGramTfIdf_) (',
#  'Name_CharGramTfIdf_, c',
#  'Name_CharGramTfIdf_, d',
#  'Name_CharGramTfIdf_, j',
#  'Name_CharGramTfIdf_, l',
#  'Name_CharGramTfIdf_, r',
#  'Name_CharGramTfIdf_, s',
#  'Name_CharGramTfIdf_, t',
#  'Name_CharGramTfIdf_-bl',
#  'Name_CharGramTfIdf_-br',
#  'Name_CharGramTfIdf_-ed',
#  'Name_CharGramTfIdf_-fr',
#  'Name_CharGramTfIdf_-he',
#  'Name_CharGramTfIdf_-je',
#  'Name_CharGramTfIdf_-la',
#  'Name_CharGramTfIdf_-ma',
#  'Name_CharGramTfIdf_-st',
#  'Name_CharGramTfIdf_-ya',
#  'Name_CharGramTfIdf_. (',
#  'Name_CharGramTfIdf_. a',
#  'Name_CharGramTfIdf_. b',
#  'Name_CharGramTfIdf_. c',
#  'Name_CharGramTfIdf_. d',
#  'Name_CharGramTfIdf_. e',
#  'Name_CharGramTfIdf_. f',
#  'Name_CharGramTfIdf_. g',
#  'Name_CharGramTfIdf_. h',
#  'Name_CharGramTfIdf_. i',
#  'Name_CharGramTfIdf_. j',
#  'Name_CharGramTfIdf_. k',
#  'Name_CharGramTfIdf_. l',
#  'Name_CharGramTfIdf_. m',
#  'Name_CharGramTfIdf_. n',
#  'Name_CharGramTfIdf_. o',
#  'Name_CharGramTfIdf_. p',
#  'Name_CharGramTfIdf_. q',
#  'Name_CharGramTfIdf_. r',
#  'Name_CharGramTfIdf_. s',
#  'Name_CharGramTfIdf_. t',
#  'Name_CharGramTfIdf_. u',
#  'Name_CharGramTfIdf_. v',
#  'Name_CharGramTfIdf_. w',
#  'Name_CharGramTfIdf_. y',
#  'Name_CharGramTfIdf_/ch',
#  'Name_CharGramTfIdf_a "',
#  'Name_CharGramTfIdf_a (',
#  'Name_CharGramTfIdf_a a',
#  'Name_CharGramTfIdf_a b',
#  'Name_CharGramTfIdf_a c',
#  'Name_CharGramTfIdf_a d',
#  'Name_CharGramTfIdf_a e',
#  'Name_CharGramTfIdf_a f',
#  'Name_CharGramTfIdf_a g',
#  'Name_CharGramTfIdf_a h',
#  'Name_CharGramTfIdf_a i',
#  'Name_CharGramTfIdf_a j',
#  'Name_CharGramTfIdf_a k',
#  'Name_CharGramTfIdf_a l',
#  'Name_CharGramTfIdf_a m',
#  'Name_CharGramTfIdf_a n',
#  'Name_CharGramTfIdf_a o',
#  'Name_CharGramTfIdf_a p',
#  'Name_CharGramTfIdf_a q',
#  'Name_CharGramTfIdf_a r',
#  'Name_CharGramTfIdf_a s',
#  'Name_CharGramTfIdf_a t',
#  'Name_CharGramTfIdf_a u',
#  'Name_CharGramTfIdf_a v',
#  'Name_CharGramTfIdf_a w',
#  'Name_CharGramTfIdf_a, ',
#  'Name_CharGramTfIdf_a-y',
#  'Name_CharGramTfIdf_aa,',
#  'Name_CharGramTfIdf_aad',
#  'Name_CharGramTfIdf_aak',
#  'Name_CharGramTfIdf_aal',
#  'Name_CharGramTfIdf_aan',
#  'Name_CharGramTfIdf_aar',
#  'Name_CharGramTfIdf_aas',
#  'Name_CharGramTfIdf_ab,',
#  'Name_CharGramTfIdf_abb',
#  'Name_CharGramTfIdf_abe',
#  'Name_CharGramTfIdf_abi',
#  'Name_CharGramTfIdf_abo',
#  'Name_CharGramTfIdf_abr',
#  'Name_CharGramTfIdf_abu',
#  'Name_CharGramTfIdf_ac,',
#  'Name_CharGramTfIdf_ace',
#  'Name_CharGramTfIdf_ach',
#  'Name_CharGramTfIdf_aci',
#  'Name_CharGramTfIdf_ack',
#  'Name_CharGramTfIdf_acl',
#  'Name_CharGramTfIdf_aco',
#  'Name_CharGramTfIdf_acq',
#  'Name_CharGramTfIdf_ad ',
#  'Name_CharGramTfIdf_ad,',
#  'Name_CharGramTfIdf_ada',
#  'Name_CharGramTfIdf_add',
#  'Name_CharGramTfIdf_ade',
#  'Name_CharGramTfIdf_adg',
#  'Name_CharGramTfIdf_adi',
#  'Name_CharGramTfIdf_adl',
#  'Name_CharGramTfIdf_ado',
#  'Name_CharGramTfIdf_adr',
#  'Name_CharGramTfIdf_ads',
#  'Name_CharGramTfIdf_adt',
#  'Name_CharGramTfIdf_ady',
#  'Name_CharGramTfIdf_ae ',
#  'Name_CharGramTfIdf_aef',
#  'Name_CharGramTfIdf_aeg',
#  'Name_CharGramTfIdf_aek',
#  'Name_CharGramTfIdf_ael',
#  'Name_CharGramTfIdf_aen',
#  'Name_CharGramTfIdf_aer',
#  'Name_CharGramTfIdf_af ',
#  'Name_CharGramTfIdf_afa',
#  'Name_CharGramTfIdf_aff',
#  'Name_CharGramTfIdf_afs',
#  'Name_CharGramTfIdf_aga',
#  'Name_CharGramTfIdf_agd',
#  'Name_CharGramTfIdf_age',
#  'Name_CharGramTfIdf_agg',
#  'Name_CharGramTfIdf_agh',
#  'Name_CharGramTfIdf_agl',
#  'Name_CharGramTfIdf_agn',
#  'Name_CharGramTfIdf_ah ',
#  'Name_CharGramTfIdf_ah"',
#  'Name_CharGramTfIdf_ah,',
#  'Name_CharGramTfIdf_aha',
#  'Name_CharGramTfIdf_ahe',
#  'Name_CharGramTfIdf_ahi',
#  'Name_CharGramTfIdf_ahl',
#  'Name_CharGramTfIdf_ahm',
#  'Name_CharGramTfIdf_aho',
#  'Name_CharGramTfIdf_aht',
#  'Name_CharGramTfIdf_ai ',
#  'Name_CharGramTfIdf_ai"',
#  'Name_CharGramTfIdf_aic',
#  'Name_CharGramTfIdf_aid',
#  'Name_CharGramTfIdf_aih',
#  'Name_CharGramTfIdf_aii',
#  'Name_CharGramTfIdf_aij',
#  'Name_CharGramTfIdf_ail',
#  'Name_CharGramTfIdf_aim',
#  'Name_CharGramTfIdf_ain',
#  'Name_CharGramTfIdf_aio',
#  'Name_CharGramTfIdf_air',
#  'Name_CharGramTfIdf_ais',
#  'Name_CharGramTfIdf_ait',
#  'Name_CharGramTfIdf_aji',
#  'Name_CharGramTfIdf_ajo',
#  'Name_CharGramTfIdf_aka',
#  'Name_CharGramTfIdf_ake',
#  'Name_CharGramTfIdf_aki',
#  'Name_CharGramTfIdf_akk',
#  'Name_CharGramTfIdf_akl',
#  'Name_CharGramTfIdf_ako',
#  'Name_CharGramTfIdf_aks',
#  'Name_CharGramTfIdf_al ',
#  'Name_CharGramTfIdf_al,',
#  'Name_CharGramTfIdf_ala',
#  'Name_CharGramTfIdf_alb',
#  'Name_CharGramTfIdf_ald',
#  'Name_CharGramTfIdf_ale',
#  'Name_CharGramTfIdf_alf',
#  'Name_CharGramTfIdf_alg',
#  'Name_CharGramTfIdf_alh',
#  'Name_CharGramTfIdf_ali',
#  'Name_CharGramTfIdf_alk',
#  'Name_CharGramTfIdf_all',
#  'Name_CharGramTfIdf_alm',
#  'Name_CharGramTfIdf_alo',
#  'Name_CharGramTfIdf_als',
#  'Name_CharGramTfIdf_alt',
#  'Name_CharGramTfIdf_alv',
#  'Name_CharGramTfIdf_aly',
#  'Name_CharGramTfIdf_am ',
#  'Name_CharGramTfIdf_am"',
#  'Name_CharGramTfIdf_am)',
#  'Name_CharGramTfIdf_am,',
#  'Name_CharGramTfIdf_ama',
#  'Name_CharGramTfIdf_amb',
#  'Name_CharGramTfIdf_ame',
#  'Name_CharGramTfIdf_ami',
#  'Name_CharGramTfIdf_amm',
#  'Name_CharGramTfIdf_amo',
#  'Name_CharGramTfIdf_amp',
#  'Name_CharGramTfIdf_ams',
#  'Name_CharGramTfIdf_amu',
#  'Name_CharGramTfIdf_amy',
#  'Name_CharGramTfIdf_an ',
#  'Name_CharGramTfIdf_an"',
#  'Name_CharGramTfIdf_an)',
#  'Name_CharGramTfIdf_an,',
#  'Name_CharGramTfIdf_ana',
#  'Name_CharGramTfIdf_anb',
#  'Name_CharGramTfIdf_anc',
#  'Name_CharGramTfIdf_and',
#  'Name_CharGramTfIdf_ane',
#  'Name_CharGramTfIdf_anf',
#  'Name_CharGramTfIdf_ang',
#  'Name_CharGramTfIdf_ani',
#  'Name_CharGramTfIdf_ank',
#  'Name_CharGramTfIdf_anl',
#  'Name_CharGramTfIdf_ann',
#  'Name_CharGramTfIdf_ano',
#  'Name_CharGramTfIdf_ans',
#  'Name_CharGramTfIdf_ant',
#  'Name_CharGramTfIdf_anu',
#  'Name_CharGramTfIdf_anw',
#  'Name_CharGramTfIdf_anz',
#  'Name_CharGramTfIdf_apm',
#  'Name_CharGramTfIdf_apo',
#  'Name_CharGramTfIdf_app',
#  'Name_CharGramTfIdf_apt',
#  'Name_CharGramTfIdf_apu',
#  'Name_CharGramTfIdf_ar ',
#  'Name_CharGramTfIdf_ara',
#  'Name_CharGramTfIdf_arb',
#  'Name_CharGramTfIdf_arc',
#  'Name_CharGramTfIdf_ard',
#  'Name_CharGramTfIdf_are',
#  'Name_CharGramTfIdf_arf',
#  'Name_CharGramTfIdf_arg',
#  'Name_CharGramTfIdf_ari',
#  'Name_CharGramTfIdf_arj',
#  'Name_CharGramTfIdf_ark',
#  'Name_CharGramTfIdf_arl',
#  'Name_CharGramTfIdf_arm',
#  'Name_CharGramTfIdf_arn',
#  'Name_CharGramTfIdf_aro',
#  'Name_CharGramTfIdf_arp',
#  'Name_CharGramTfIdf_arr',
#  'Name_CharGramTfIdf_ars',
#  'Name_CharGramTfIdf_art',
#  'Name_CharGramTfIdf_aru',
#  'Name_CharGramTfIdf_arv',
#  'Name_CharGramTfIdf_arw',
#  'Name_CharGramTfIdf_ary',
#  'Name_CharGramTfIdf_as ',
#  'Name_CharGramTfIdf_as)',
#  'Name_CharGramTfIdf_as,',
#  'Name_CharGramTfIdf_asa',
#  'Name_CharGramTfIdf_asb',
#  'Name_CharGramTfIdf_asc',
#  'Name_CharGramTfIdf_ase',
#  'Name_CharGramTfIdf_ash',
#  'Name_CharGramTfIdf_asi',
#  'Name_CharGramTfIdf_ask',
#  'Name_CharGramTfIdf_asp',
#  'Name_CharGramTfIdf_ass',
#  'Name_CharGramTfIdf_ast',
#  'Name_CharGramTfIdf_asu',
#  'Name_CharGramTfIdf_ata',
#  'Name_CharGramTfIdf_atc',
#  'Name_CharGramTfIdf_ate',
#  'Name_CharGramTfIdf_atf',
#  'Name_CharGramTfIdf_ath',
#  'Name_CharGramTfIdf_ati',
#  'Name_CharGramTfIdf_atk',
#  'Name_CharGramTfIdf_ato',
#  'Name_CharGramTfIdf_atr',
#  'Name_CharGramTfIdf_ats',
#  'Name_CharGramTfIdf_att',
#  'Name_CharGramTfIdf_au,',
#  'Name_CharGramTfIdf_aub',
#  'Name_CharGramTfIdf_aud',
#  'Name_CharGramTfIdf_aue',
#  'Name_CharGramTfIdf_aug',
#  'Name_CharGramTfIdf_aul',
#  'Name_CharGramTfIdf_aum',
#  'Name_CharGramTfIdf_aun',
#  'Name_CharGramTfIdf_aur',
#  'Name_CharGramTfIdf_aus',
#  'Name_CharGramTfIdf_ava',
#  'Name_CharGramTfIdf_ave',
#  'Name_CharGramTfIdf_avi',
#  'Name_CharGramTfIdf_avl',
#  'Name_CharGramTfIdf_avr',
#  'Name_CharGramTfIdf_awa',
#  'Name_CharGramTfIdf_awe',
#  'Name_CharGramTfIdf_awk',
#  'Name_CharGramTfIdf_awr',
#  'Name_CharGramTfIdf_awy',
#  'Name_CharGramTfIdf_axf',
#  'Name_CharGramTfIdf_axm',
#  'Name_CharGramTfIdf_axt',
#  'Name_CharGramTfIdf_ay ',
#  'Name_CharGramTfIdf_aya',
#  'Name_CharGramTfIdf_ayb',
#  'Name_CharGramTfIdf_ayd',
#  'Name_CharGramTfIdf_aye',
#  'Name_CharGramTfIdf_ayl',
#  'Name_CharGramTfIdf_ayn',
#  'Name_CharGramTfIdf_ayo',
#  'Name_CharGramTfIdf_ays',
#  'Name_CharGramTfIdf_ayt',
#  'Name_CharGramTfIdf_aze',
#  'Name_CharGramTfIdf_azi',
#  'Name_CharGramTfIdf_azl',
#  'Name_CharGramTfIdf_azz',
#  'Name_CharGramTfIdf_b (',
#  'Name_CharGramTfIdf_b a',
#  'Name_CharGramTfIdf_b c',
#  'Name_CharGramTfIdf_b, ',
#  'Name_CharGramTfIdf_ba ',
#  'Name_CharGramTfIdf_bac',
#  'Name_CharGramTfIdf_bad',
#  'Name_CharGramTfIdf_bai',
#  'Name_CharGramTfIdf_bal',
#  'Name_CharGramTfIdf_ban',
#  'Name_CharGramTfIdf_bap',
#  'Name_CharGramTfIdf_bar',
#  'Name_CharGramTfIdf_bas',
#  'Name_CharGramTfIdf_bat',
#  'Name_CharGramTfIdf_bau',
#  'Name_CharGramTfIdf_bax',
#  'Name_CharGramTfIdf_baz',
#  'Name_CharGramTfIdf_bb,',
#  'Name_CharGramTfIdf_bba',
#  'Name_CharGramTfIdf_bbe',
#  'Name_CharGramTfIdf_bbi',
#  'Name_CharGramTfIdf_bbo',
#  'Name_CharGramTfIdf_bea',
#  'Name_CharGramTfIdf_bec',
#  'Name_CharGramTfIdf_bee',
#  'Name_CharGramTfIdf_beh',
#  'Name_CharGramTfIdf_bei',
#  'Name_CharGramTfIdf_bek',
#  'Name_CharGramTfIdf_bel',
#  'Name_CharGramTfIdf_ben',
#  'Name_CharGramTfIdf_ber',
#  'Name_CharGramTfIdf_bes',
#  'Name_CharGramTfIdf_bet',
#  'Name_CharGramTfIdf_bey',
#  'Name_CharGramTfIdf_bia',
#  'Name_CharGramTfIdf_bid',
#  'Name_CharGramTfIdf_bil',
#  'Name_CharGramTfIdf_bim',
#  'Name_CharGramTfIdf_bin',
#  'Name_CharGramTfIdf_bir',
#  'Name_CharGramTfIdf_bis',
#  'Name_CharGramTfIdf_bjo',
#  'Name_CharGramTfIdf_bla',
#  'Name_CharGramTfIdf_ble',
#  'Name_CharGramTfIdf_bli',
#  'Name_CharGramTfIdf_blo',
#  'Name_CharGramTfIdf_blu',
#  'Name_CharGramTfIdf_bly',
#  'Name_CharGramTfIdf_bna',
#  'Name_CharGramTfIdf_bom',
#  'Name_CharGramTfIdf_bon',
#  'Name_CharGramTfIdf_boo',
#  'Name_CharGramTfIdf_bor',
#  'Name_CharGramTfIdf_bos',
#  'Name_CharGramTfIdf_bot',
#  'Name_CharGramTfIdf_bou',
#  'Name_CharGramTfIdf_bow',
#  'Name_CharGramTfIdf_bra',
#  'Name_CharGramTfIdf_bre',
#  'Name_CharGramTfIdf_bri',
#  'Name_CharGramTfIdf_bro',
#  'Name_CharGramTfIdf_bry',
#  'Name_CharGramTfIdf_bso',
#  'Name_CharGramTfIdf_bst',
#  'Name_CharGramTfIdf_bul',
#  'Name_CharGramTfIdf_bum',
#  'Name_CharGramTfIdf_bur',
#  'Name_CharGramTfIdf_bus',
#  'Name_CharGramTfIdf_but',
#  'Name_CharGramTfIdf_by"',
#  'Name_CharGramTfIdf_by)',
#  'Name_CharGramTfIdf_by,',
#  'Name_CharGramTfIdf_byl',
#  'Name_CharGramTfIdf_bys',
#  'Name_CharGramTfIdf_c (',
#  'Name_CharGramTfIdf_c k',
#  'Name_CharGramTfIdf_c o',
#  'Name_CharGramTfIdf_c r',
#  'Name_CharGramTfIdf_c, ',
#  'Name_CharGramTfIdf_ca,',
#  'Name_CharGramTfIdf_cac',
#  'Name_CharGramTfIdf_cah',
#  'Name_CharGramTfIdf_cai',
#  'Name_CharGramTfIdf_cal',
#  'Name_CharGramTfIdf_cam',
#  'Name_CharGramTfIdf_can',
#  'Name_CharGramTfIdf_cap',
#  'Name_CharGramTfIdf_car',
#  'Name_CharGramTfIdf_cas',
#  'Name_CharGramTfIdf_cat',
#  'Name_CharGramTfIdf_cav',
#  'Name_CharGramTfIdf_cca',
#  'Name_CharGramTfIdf_cco',
#  'Name_CharGramTfIdf_cde',
#  'Name_CharGramTfIdf_ce ',
#  'Name_CharGramTfIdf_ce)',
#  'Name_CharGramTfIdf_ce,',
#  'Name_CharGramTfIdf_cel',
#  'Name_CharGramTfIdf_cen',
#  'Name_CharGramTfIdf_cer',
#  'Name_CharGramTfIdf_ces',
#  'Name_CharGramTfIdf_cev',
#  'Name_CharGramTfIdf_cgo',
#  'Name_CharGramTfIdf_ch ',
#  'Name_CharGramTfIdf_ch)',
#  'Name_CharGramTfIdf_ch,',
#  'Name_CharGramTfIdf_cha',
#  'Name_CharGramTfIdf_chc',
#  'Name_CharGramTfIdf_che',
#  'Name_CharGramTfIdf_chi',
#  'Name_CharGramTfIdf_chl',
#  'Name_CharGramTfIdf_chm',
#  'Name_CharGramTfIdf_cho',
#  'Name_CharGramTfIdf_chr',
#  'Name_CharGramTfIdf_chs',
#  'Name_CharGramTfIdf_chu',
#  'Name_CharGramTfIdf_cic',
#  'Name_CharGramTfIdf_cie',
#  'Name_CharGramTfIdf_cil',
#  'Name_CharGramTfIdf_cin',
#  'Name_CharGramTfIdf_cio',
#  'Name_CharGramTfIdf_cis',
#  'Name_CharGramTfIdf_civ',
#  'Name_CharGramTfIdf_ck ',
#  'Name_CharGramTfIdf_ck"',
#  'Name_CharGramTfIdf_ck)',
#  'Name_CharGramTfIdf_ck,',
#  'Name_CharGramTfIdf_cka',
#  'Name_CharGramTfIdf_cke',
#  'Name_CharGramTfIdf_cki',
#  'Name_CharGramTfIdf_ckl',
#  'Name_CharGramTfIdf_ckm',
#  'Name_CharGramTfIdf_cko',
#  'Name_CharGramTfIdf_cks',
#  'Name_CharGramTfIdf_ckw',
#  'Name_CharGramTfIdf_cla',
#  'Name_CharGramTfIdf_cle',
#  'Name_CharGramTfIdf_cli',
#  'Name_CharGramTfIdf_cly',
#  'Name_CharGramTfIdf_cma',
#  'Name_CharGramTfIdf_cmi',
#  'Name_CharGramTfIdf_cna',
#  'Name_CharGramTfIdf_co ',
#  'Name_CharGramTfIdf_cob',
#  'Name_CharGramTfIdf_coc',
#  'Name_CharGramTfIdf_coe',
#  'Name_CharGramTfIdf_cof',
#  'Name_CharGramTfIdf_coh',
#  'Name_CharGramTfIdf_coi',
#  'Name_CharGramTfIdf_col',
#  'Name_CharGramTfIdf_com',
#  'Name_CharGramTfIdf_con',
#  'Name_CharGramTfIdf_coo',
#  'Name_CharGramTfIdf_cor',
#  'Name_CharGramTfIdf_cos',
#  'Name_CharGramTfIdf_cot',
#  'Name_CharGramTfIdf_cou',
#  'Name_CharGramTfIdf_cov',
#  'Name_CharGramTfIdf_cox',
#  'Name_CharGramTfIdf_coy',
#  'Name_CharGramTfIdf_cqu',
#  'Name_CharGramTfIdf_cre',
#  'Name_CharGramTfIdf_cri',
#  'Name_CharGramTfIdf_cro',
#  'Name_CharGramTfIdf_cru',
#  'Name_CharGramTfIdf_cto',
#  'Name_CharGramTfIdf_cul',
#  'Name_CharGramTfIdf_cum',
#  'Name_CharGramTfIdf_cun',
#  'Name_CharGramTfIdf_cur',
#  'Name_CharGramTfIdf_cy ',
#  'Name_CharGramTfIdf_cyr',
#  'Name_CharGramTfIdf_d "',
#  'Name_CharGramTfIdf_d (',
#  'Name_CharGramTfIdf_d a',
#  'Name_CharGramTfIdf_d b',
#  'Name_CharGramTfIdf_d c',
#  'Name_CharGramTfIdf_d d',
#  'Name_CharGramTfIdf_d e',
#  'Name_CharGramTfIdf_d f',
#  'Name_CharGramTfIdf_d g',
#  'Name_CharGramTfIdf_d h',
#  'Name_CharGramTfIdf_d j',
#  'Name_CharGramTfIdf_d k',
#  'Name_CharGramTfIdf_d l',
#  'Name_CharGramTfIdf_d m',
#  'Name_CharGramTfIdf_d o',
#  'Name_CharGramTfIdf_d p',
#  'Name_CharGramTfIdf_d r',
#  'Name_CharGramTfIdf_d s',
#  'Name_CharGramTfIdf_d t',
#  'Name_CharGramTfIdf_d v',
#  'Name_CharGramTfIdf_d w',
#  'Name_CharGramTfIdf_d) ',
#  'Name_CharGramTfIdf_d, ',
#  'Name_CharGramTfIdf_d-f',
#  'Name_CharGramTfIdf_da ',
#  'Name_CharGramTfIdf_dah',
#  'Name_CharGramTfIdf_dai',
#  'Name_CharGramTfIdf_dak',
#  'Name_CharGramTfIdf_dal',
#  'Name_CharGramTfIdf_dam',
#  'Name_CharGramTfIdf_dan',
#  'Name_CharGramTfIdf_dar',
#  'Name_CharGramTfIdf_dav',
#  'Name_CharGramTfIdf_dbe',
#  'Name_CharGramTfIdf_dbl',
#  'Name_CharGramTfIdf_dd,',
#  'Name_CharGramTfIdf_dde',
#  'Name_CharGramTfIdf_ddi',
#  'Name_CharGramTfIdf_de ',
#  'Name_CharGramTfIdf_de)',
#  'Name_CharGramTfIdf_de,',
#  'Name_CharGramTfIdf_dea',
#  'Name_CharGramTfIdf_def',
#  'Name_CharGramTfIdf_deg',
#  'Name_CharGramTfIdf_dek',
#  'Name_CharGramTfIdf_del',
#  'Name_CharGramTfIdf_dem',
#  'Name_CharGramTfIdf_den',
#  'Name_CharGramTfIdf_deo',
#  'Name_CharGramTfIdf_der',
#  'Name_CharGramTfIdf_det',
#  'Name_CharGramTfIdf_dev',
#  'Name_CharGramTfIdf_dez',
#  'Name_CharGramTfIdf_dfr',
#  'Name_CharGramTfIdf_dga',
#  'Name_CharGramTfIdf_dge',
#  'Name_CharGramTfIdf_dgw',
#  'Name_CharGramTfIdf_dib',
#  'Name_CharGramTfIdf_dic',
#  'Name_CharGramTfIdf_dig',
#  'Name_CharGramTfIdf_dil',
#  'Name_CharGramTfIdf_dim',
#  'Name_CharGramTfIdf_din',
#  'Name_CharGramTfIdf_dis',
#  'Name_CharGramTfIdf_dit',
#  'Name_CharGramTfIdf_dla',
#  'Name_CharGramTfIdf_dle',
#  'Name_CharGramTfIdf_dli',
#  'Name_CharGramTfIdf_dma',
#  'Name_CharGramTfIdf_dme',
#  'Name_CharGramTfIdf_dmo',
#  'Name_CharGramTfIdf_dmu',
#  'Name_CharGramTfIdf_dne',
#  'Name_CharGramTfIdf_do ',
#  'Name_CharGramTfIdf_do,',
#  'Name_CharGramTfIdf_dod',
#  'Name_CharGramTfIdf_doh',
#  'Name_CharGramTfIdf_doi',
#  'Name_CharGramTfIdf_dol',
#  'Name_CharGramTfIdf_dom',
#  'Name_CharGramTfIdf_don',
#  'Name_CharGramTfIdf_doo',
#  'Name_CharGramTfIdf_dor',
#  'Name_CharGramTfIdf_dos',
#  'Name_CharGramTfIdf_dot',
#  'Name_CharGramTfIdf_dou',
#  'Name_CharGramTfIdf_dow',
#  'Name_CharGramTfIdf_dqv',
#  'Name_CharGramTfIdf_dr.',
#  'Name_CharGramTfIdf_dra',
#  'Name_CharGramTfIdf_dre',
#  'Name_CharGramTfIdf_dri',
#  'Name_CharGramTfIdf_dro',
#  'Name_CharGramTfIdf_ds)',
#  'Name_CharGramTfIdf_ds,',
#  'Name_CharGramTfIdf_dsc',
#  'Name_CharGramTfIdf_dsd',
#  'Name_CharGramTfIdf_dse',
#  'Name_CharGramTfIdf_dsm',
#  'Name_CharGramTfIdf_dso',
#  'Name_CharGramTfIdf_dss',
#  'Name_CharGramTfIdf_dst',
#  'Name_CharGramTfIdf_dt ',
#  'Name_CharGramTfIdf_dt,',
#  'Name_CharGramTfIdf_dtj',
#  'Name_CharGramTfIdf_dua',
#  'Name_CharGramTfIdf_duf',
#  'Name_CharGramTfIdf_dur',
#  'Name_CharGramTfIdf_dus',
#  'Name_CharGramTfIdf_duz',
#  'Name_CharGramTfIdf_dva',
#  'Name_CharGramTfIdf_dvi',
#  'Name_CharGramTfIdf_dwa',
#  'Name_CharGramTfIdf_dwe',
#  'Name_CharGramTfIdf_dwi',
#  'Name_CharGramTfIdf_dwy',
#  'Name_CharGramTfIdf_dy"',
#  'Name_CharGramTfIdf_dy.',
#  'Name_CharGramTfIdf_dyc',
#  'Name_CharGramTfIdf_dye',
#  'Name_CharGramTfIdf_dys',
#  'Name_CharGramTfIdf_e "',
#  'Name_CharGramTfIdf_e (',
#  'Name_CharGramTfIdf_e a',
#  'Name_CharGramTfIdf_e b',
#  'Name_CharGramTfIdf_e c',
#  'Name_CharGramTfIdf_e d',
#  'Name_CharGramTfIdf_e e',
#  'Name_CharGramTfIdf_e f',
#  'Name_CharGramTfIdf_e g',
#  'Name_CharGramTfIdf_e h',
#  'Name_CharGramTfIdf_e j',
#  'Name_CharGramTfIdf_e k',
#  'Name_CharGramTfIdf_e l',
#  'Name_CharGramTfIdf_e m',
#  'Name_CharGramTfIdf_e n',
#  'Name_CharGramTfIdf_e p',
#  'Name_CharGramTfIdf_e q',
#  'Name_CharGramTfIdf_e r',
#  'Name_CharGramTfIdf_e s',
#  'Name_CharGramTfIdf_e t',
#  'Name_CharGramTfIdf_e v',
#  'Name_CharGramTfIdf_e w',
#  'Name_CharGramTfIdf_e y',
#  'Name_CharGramTfIdf_e" ',
#  'Name_CharGramTfIdf_e")',
#  'Name_CharGramTfIdf_e) ',
#  'Name_CharGramTfIdf_e, ',
#  'Name_CharGramTfIdf_e. ',
#  'Name_CharGramTfIdf_ead',
#  'Name_CharGramTfIdf_eah',
#  'Name_CharGramTfIdf_eal',
#  'Name_CharGramTfIdf_ean',
#  'Name_CharGramTfIdf_ear',
#  'Name_CharGramTfIdf_eas',
#  'Name_CharGramTfIdf_eat',
#  'Name_CharGramTfIdf_eau',
#  'Name_CharGramTfIdf_eav',
#  'Name_CharGramTfIdf_eba',
#  'Name_CharGramTfIdf_ebb',
#  'Name_CharGramTfIdf_ebe',
#  'Name_CharGramTfIdf_ebl',
#  'Name_CharGramTfIdf_ebo',
#  'Name_CharGramTfIdf_ebr',
#  'Name_CharGramTfIdf_ebs',
#  'Name_CharGramTfIdf_ec,',
#  'Name_CharGramTfIdf_eca',
#  'Name_CharGramTfIdf_ecc',
#  'Name_CharGramTfIdf_ech',
#  'Name_CharGramTfIdf_eck',
#  'Name_CharGramTfIdf_ed ',
#  'Name_CharGramTfIdf_ed"',
#  'Name_CharGramTfIdf_ed,',
#  'Name_CharGramTfIdf_edd',
#  'Name_CharGramTfIdf_ede',
#  'Name_CharGramTfIdf_edg',
#  'Name_CharGramTfIdf_edi',
#  'Name_CharGramTfIdf_edm',
#  'Name_CharGramTfIdf_edr',
#  'Name_CharGramTfIdf_eds',
#  'Name_CharGramTfIdf_edt',
#  'Name_CharGramTfIdf_edu',
#  'Name_CharGramTfIdf_edv',
#  'Name_CharGramTfIdf_edw',
#  'Name_CharGramTfIdf_ee,',
#  'Name_CharGramTfIdf_eed',
#  'Name_CharGramTfIdf_eef',
#  'Name_CharGramTfIdf_eek',
#  'Name_CharGramTfIdf_eel',
#  'Name_CharGramTfIdf_een',
#  'Name_CharGramTfIdf_eep',
#  'Name_CharGramTfIdf_eer',
#  'Name_CharGramTfIdf_ees',
#  'Name_CharGramTfIdf_eev',
#  ...]

# %%
# Copy-pasted this part from the doc.
from pprint import pprint

def print_model(model, prefix=""):
    for step in model.steps:
        print(prefix + step[0])
        if hasattr(step[1], 'estimators') and hasattr(step[1], 'weights'):
            pprint({'estimators': list(
                e[0] for e in step[1].estimators), 'weights': step[1].weights})
            print()
            for estimator in step[1].estimators:
                print_model(estimator[1], estimator[0] + ' - ')
        else:
            pprint(step[1].get_params())
            print()


print_model(fitted_model)
# Out:
# datatransformer
# {'enable_dnn': None,
#  'enable_feature_sweeping': None,
#  'feature_sweeping_config': None,
#  'feature_sweeping_timeout': None,
#  'featurization_config': None,
#  'is_cross_validation': None,
#  'is_onnx_compatible': None,
#  'logger': None,
#  'observer': None,
#  'task': None}
#
# prefittedsoftvotingclassifier
# {'estimators': ['0', '2', '1', '3'],
#  'weights': [0.35714285714285715,
#              0.21428571428571427,
#              0.2857142857142857,
#              0.14285714285714285]}
#
# 0 - maxabsscaler
# {'copy': True}
#
# 0 - lightgbmclassifier
# {'boosting_type': 'goss',
#  'class_weight': None,
#  'colsample_bytree': 0.7922222222222222,
#  'importance_type': 'split',
#  'learning_rate': 0.1,
#  'max_bin': 170,
#  'max_depth': 4,
#  'min_child_samples': 34,
#  'min_child_weight': 4,
#  'min_split_gain': 0.8421052631578947,
#  'n_estimators': 50,
#  'n_jobs': 1,
#  'num_leaves': 62,
#  'objective': None,
#  'random_state': None,
#  'reg_alpha': 0.7894736842105263,
#  'reg_lambda': 0.15789473684210525,
#  'silent': True,
#  'subsample': 1,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0,
#  'verbose': -10}
#
# 2 - standardscalerwrapper
# {'class_name': 'StandardScaler',
#  'copy': True,
#  'module_name': 'sklearn.preprocessing.data',
#  'with_mean': False,
#  'with_std': False}
#
# 2 - lightgbmclassifier
# {'boosting_type': 'gbdt',
#  'class_weight': None,
#  'colsample_bytree': 0.6933333333333332,
#  'importance_type': 'split',
#  'learning_rate': 0.07894947368421053,
#  'max_bin': 240,
#  'max_depth': 3,
#  'min_child_samples': 16,
#  'min_child_weight': 6,
#  'min_split_gain': 0.631578947368421,
#  'n_estimators': 50,
#  'n_jobs': 1,
#  'num_leaves': 65,
#  'objective': None,
#  'random_state': None,
#  'reg_alpha': 0.5789473684210527,
#  'reg_lambda': 0.631578947368421,
#  'silent': True,
#  'subsample': 0.3963157894736842,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0,
#  'verbose': -10}
#
# 1 - maxabsscaler
# {'copy': True}
#
# 1 - sgdclassifierwrapper
# {'alpha': 8.775522448979592,
#  'class_weight': 'balanced',
#  'eta0': 0.01,
#  'fit_intercept': True,
#  'l1_ratio': 0.8775510204081632,
#  'learning_rate': 'constant',
#  'loss': 'log',
#  'max_iter': 1000,
#  'n_jobs': 1,
#  'penalty': 'none',
#  'power_t': 0.2222222222222222,
#  'random_state': None,
#  'tol': 0.01}
#
# 3 - maxabsscaler
# {'copy': True}
#
# 3 - randomforestclassifier
# {'bootstrap': False,
#  'class_weight': 'balanced',
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 0.06157894736842105,
#  'min_samples_split': 0.15052631578947367,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 25,
#  'n_jobs': 1,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# from azureml.train.automl import AutoMLConfig
# # https://docs.microsoft.com/en-us/azure/machine-learning/service/how-to-configure-auto-train#configure-your-experiment-settings
# # https://docs.microsoft.com/en-us/python/api/azureml-train-automl/azureml.train.automl.automlconfig?view=azure-ml-py
# automl_config = AutoMLConfig(
#     task='classification',
#     training_data=df,
#     label_column_name='Survived',
#     primary_metric='AUC_weighted',
#     n_cross_validations=2,
    
#     # Try for at most 10 minutes, then give up.
#     experiment_timeout_minutes=1,
    
#     # Featurization
#     preprocess=True,
#     feauturization=featurization_config,
    
#     debug_log="automated_ml_errors.log",
#     verbosity=logging.INFO)

# %% [markdown]
# ## NOTE: No direct support to take apart the AutoML pipeline, e.g. use just Featurization.
#
# ## Configuring Featurization
#
# If the pipeline made a mistake, you can specify a `FeaturizationConfig` and re-run.
#
# We can use this to, for example, block the tf-idf features on text.
#
# ```
# featurization_config = FeaturizationConfig()
# featurization_config.blocked_transformers = ['LabelEncoder']
# featurization_config.drop_columns = ['aspiration', 'stroke']
# featurization_config.add_column_purpose('engine-size', 'Numeric')
# featurization_config.add_column_purpose('body-style', 'CategoricalHash')
# featurization_config.add_transformer_params('Imputer', ['engine-size'], {"strategy": "median"})
# featurization_config.add_transformer_params('Imputer', ['city-mpg'], {"strategy": "median"})
# featurization_config.add_transformer_params('Imputer', ['bore'], {"strategy": "most_frequent"})
# featurization_config.add_transformer_params('HashOneHotEncoder', [], {"number_of_bits": 3})
#
# ...
#
# automl_config = AutoMLConfig(
#     ...
#     "feauturization": FeaturizationConfig
#     )
# ```
#
# See:
# - https://docs.microsoft.com/en-us/python/api/azureml-train-automl/azureml.train.automl.automlconfig?view=azure-ml-py

# %%
from azureml.automl.core.featurization.featurizationconfig import FeaturizationConfig
#FeaturizationConfig?
